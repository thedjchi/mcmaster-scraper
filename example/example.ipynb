# %%
from example import main

await main()
# Out:
#      Grouping 1                                        Material    Lg.     OD  \
# 7      Loop End                                    Spring Steel  0.310  0.063
# 1280   Loop End         Corrosion-Resistant 302 Stainless Steel  0.313  0.063
# 2291   Hook End                                    Spring Steel  0.310  0.063
# 3907   Hook End  Highly Corrosion-Resistant 316 Stainless Steel  0.313  0.063
#
#       WireDia.  Extended Lg.@ Max. Load  Min. Load,lb.  Max. Load,lb.  \
# 7        0.011                    0.440           0.10           1.09
# 1280     0.011                    0.440           0.08           0.91
# 2291     0.011                    0.440           0.10           1.09
# 3907     0.011                    0.445           0.10           1.14
#
#       Spring Rate, lbf/in  Pkg.Qty.             Pkg.
# 7                    7.90       5.0  5108N021  14.60
# 1280                 6.58       3.0  7749N008  13.08
# 2291                 7.90       5.0  7383N132  15.28
# ...
